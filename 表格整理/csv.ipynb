# %%
import csv 
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("/Users/wutzu/Desktop/KPMG/財報資料/寒舍_2739/資產負債表/2739_110_4_資產負債表.csv",index_col="民國110年第4季")
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
data.rename(columns={"民國110年第4季.1":"110-4","民國110年第4季.3":"109-4",},inplace=True)
new=data.drop(['民國110年第4季.5','民國110年第4季.6','民國110年第4季.2','民國110年第4季.4','Unnamed: 0'],axis=1)
new1=new.drop(['單位：新台幣仟元','會計項目','Unnamed: 0_level_3'])
new1.head(63)
# Out:
#                                   110-4       109-4
# 民國110年第4季
# 流動資產                                NaN         NaN
# 現金及約當現金                        315657.0    424717.0
# 透過損益按公允價值衡量之金融資產－流動            183216.0    190049.0
# 按攤銷後成本衡量之金融資產－流動               247704.0    227398.0
# 應收票據淨額                            647.0       377.0
# 應收帳款淨額                          44248.0     34913.0
# 應收帳款－關係人淨額                       5273.0      9543.0
# 其他應收款淨額                          4880.0     18809.0
# 其他應收款－關係人淨額                      2472.0      1444.0
# 本期所得稅資產                           113.0     12153.0
# 存貨                              78281.0     79076.0
# 預付款項                            33170.0     26612.0
# 流動資產合計                         915661.0   1025091.0
# 非流動資產                               NaN         NaN
# 採用權益法之投資                        52159.0     98441.0
# 不動產、廠房及設備                     1063779.0   1151658.0
# 使用權資產                        10275385.0  11218659.0
# ...

# %%
data = pd.read_csv("/Users/wutzu/Desktop/KPMG/財報資料/寒舍_2739/資產負債表/2739_110_4_資產負債表.csv")
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
data.rename(columns={"民國110年第4季.1":"110-4","民國110年第4季.3":"109-4",},inplace=True)
new=data.drop(['民國110年第4季.5','民國110年第4季.6','民國110年第4季.2','民國110年第4季.4','Unnamed: 0'],axis=1)
new1=new.drop(index=[0,1,2],axis=1)
new1.head(63)
# Out:
#                       民國110年第4季       110-4       109-4
# 3                          流動資產         NaN         NaN
# 4                       現金及約當現金    315657.0    424717.0
# 5           透過損益按公允價值衡量之金融資產－流動    183216.0    190049.0
# 6              按攤銷後成本衡量之金融資產－流動    247704.0    227398.0
# 7                        應收票據淨額       647.0       377.0
# 8                        應收帳款淨額     44248.0     34913.0
# 9                    應收帳款－關係人淨額      5273.0      9543.0
# 10                      其他應收款淨額      4880.0     18809.0
# 11                  其他應收款－關係人淨額      2472.0      1444.0
# 12                      本期所得稅資產       113.0     12153.0
# 13                           存貨     78281.0     79076.0
# 14                         預付款項     33170.0     26612.0
# 15                       流動資產合計    915661.0   1025091.0
# 16                        非流動資產         NaN         NaN
# 17                     採用權益法之投資     52159.0     98441.0
# 18                    不動產、廠房及設備   1063779.0   1151658.0
# ...

# %%
###df1=流動資產
df1=new1[0:13]
df1.head(13)
# Out:
#               民國110年第4季     110-4      109-4
# 3                  流動資產       NaN        NaN
# 4               現金及約當現金  315657.0   424717.0
# 5   透過損益按公允價值衡量之金融資產－流動  183216.0   190049.0
# 6      按攤銷後成本衡量之金融資產－流動  247704.0   227398.0
# 7                應收票據淨額     647.0      377.0
# 8                應收帳款淨額   44248.0    34913.0
# 9            應收帳款－關係人淨額    5273.0     9543.0
# 10              其他應收款淨額    4880.0    18809.0
# 11          其他應收款－關係人淨額    2472.0     1444.0
# 12              本期所得稅資產     113.0    12153.0
# 13                   存貨   78281.0    79076.0
# 14                 預付款項   33170.0    26612.0
# 15               流動資產合計  915661.0  1025091.0

# %%
### df2=非流動資產
df2=new1[13:23]
df2.head(10)
# Out:
#     民國110年第4季       110-4       109-4
# 16      非流動資產         NaN         NaN
# 17   採用權益法之投資     52159.0     98441.0
# 18  不動產、廠房及設備   1063779.0   1151658.0
# 19      使用權資產  10275385.0  11218659.0
# 20   投資性不動產淨額    581857.0    582814.0
# 21       無形資產      7316.0      2586.0
# 22    遞延所得稅資產    352893.0    168067.0
# 23    其他非流動資產    380316.0    413980.0
# 24    非流動資產合計  12713705.0  13636205.0
# 25       資產總額  13629366.0  14661296.0

# %%
### df3=流動負債 
df3=new1[23:34]
df3.head(11)
# Out:
#      民國110年第4季      110-4      109-4
# 26        流動負債        NaN        NaN
# 27        短期借款    22800.0    24800.0
# 28     合約負債－流動   622656.0   531924.0
# 29        應付票據     3330.0     4015.0
# 30        應付帳款   196898.0   159977.0
# 31       其他應付款   575980.0   406508.0
# 32  其他應付款項－關係人     3114.0     9973.0
# 33     本期所得稅負債      781.0      712.0
# 34     租賃負債－流動   885283.0   858484.0
# 35      其他流動負債    31616.0    16903.0
# 36      流動負債合計  2342458.0  2013296.0

# %%
### df4=非流動負債
df4=new1[34:39]
df4.head(5)
# Out:
#    民國110年第4季       110-4       109-4
# 37     非流動負債         NaN         NaN
# 38      長期借款    330312.0     84087.0
# 39  租賃負債－非流動  10032606.0  10912222.0
# 40   其他非流動負債    122218.0    146742.0
# 41   非流動負債合計  10485136.0  11143051.0

# %%
df5=new1[40:44]
df5.head(4)
# Out:
#       民國110年第4季      110-4      109-4
# 43  歸屬於母公司業主之權益        NaN        NaN
# 44           股本        NaN        NaN
# 45        普通股股本  1115260.0  1115260.0
# 46         股本合計  1115260.0  1115260.0

# %%
df6=new1[44:47]
df6.head()
# Out:
#     民國110年第4季     110-4     109-4
# 47       資本公積       NaN       NaN
# 48  資本公積－發行溢價  456438.0  456438.0
# 49     資本公積合計  456438.0  456438.0

# %%
df7=new1[47:53]
df7.head()
# Out:
#         民國110年第4季      110-4      109-4
# 50           保留盈餘        NaN        NaN
# 51         法定盈餘公積        0.0   183582.0
# 52         特別盈餘公積        0.0    23678.0
# 53  未分配盈餘（或待彌補虧損）  -799906.0  -317948.0
# 54         保留盈餘合計  -799906.0  -110688.0

# %%
df8=new1[53:57]
df8.head()
# Out:
#                       民國110年第4季     110-4      109-4
# 56  透過其他綜合損益按公允價值衡量之金融資產未實現評價損益   29980.0    43939.0
# 57                       其他權益合計   29980.0    43939.0
# 58                歸屬於母公司業主之權益合計  801772.0  1504949.0
# 59                         權益總額  801772.0  1504949.0

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 62
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-59f0f94a2958> in <module>
# ----> 1 total=new1[62]
# ...
